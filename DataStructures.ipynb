# %% [markdown]
# ## String Concatenation

# %% [markdown]
# ### A Python program that takes two strings i.e string 1 "Hello ", string 2 get name as input from the user and concatenates them together and display result and add string 3 ", welcome to Python programming" to the existing string and display the output string.

# %%
string1="Hello"

# %%
string2=input("Enter your name: ")
# Out:
# Enter your name:  Sini

# %%
result = (string1 +" "+ string2)

# %%
print(result)
# Out:
# Hello Sini

# %%
string3 = ", Welcome to Python programming"

# %%
concatenated_String=result+s3

# %%
print(concatenated_String)
# Out:
# Hello Sini, Welcome to Python programming

# %% [markdown]
# ## String Slicing and Indexing

# %% [markdown]
# ### A Python program using the above concatenated string as input and performs the following tasks:

# %%
List = list(concatenated_String)

# %%
L1 = list[string1,string2,string3]

# %%
print(List)
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'S', 'i', 'n', 'i', ',', ' ', 'W', 'e', 'l', 'c', 'o', 'm', 'e', ' ', 't', 'o', ' ', 'P', 'y', 't', 'h', 'o', 'n', ' ', 'p', 'r', 'o', 'g', 'r', 'a', 'm', 'm', 'i', 'n', 'g']

# %% [markdown]
# ##### 1.Print the first character of the string.

# %%
List[0]
# Out:
# 'H'

# %% [markdown]
# ##### 2.Print the last character of the string.

# %%
List[-1]
# Out:
# 'g'

# %% [markdown]
# ##### 3.Print the first 5 characters of the string.

# %%
List[0:5]
# Out:
# ['H', 'e', 'l', 'l', 'o']

# %% [markdown]
# ##### 4.Print the last 11 characters of the string.

# %%
List[-11:]
# Out:
# ['p', 'r', 'o', 'g', 'r', 'a', 'm', 'm', 'i', 'n', 'g']

# %% [markdown]
# ##### 5.Print the string in reverse.

# %%
List[::-1]
# Out:
# ['g',
#  'n',
#  'i',
#  'm',
#  'm',
#  'a',
#  'r',
#  'g',
#  'o',
#  'r',
#  'p',
#  ' ',
#  'n',
#  'o',
#  'h',
#  't',
#  'y',
#  'P',
#  ' ',
#  'o',
#  't',
#  ' ',
#  'e',
#  'm',
#  'o',
#  'c',
#  'l',
#  'e',
#  'W',
#  ' ',
#  ',',
#  'i',
#  'n',
#  'i',
#  'S',
#  ' ',
#  'o',
#  'l',
#  'l',
#  'e',
#  'H']

# %% [markdown]
# ##### 6.Use slicing and print the word “Python” from the existing string.

# %%
List[-18:-12]
# Out:
# ['P', 'y', 't', 'h', 'o', 'n']

# %%
s = List[-18:-12]

# %%
string = ''.join(s)

# %%
print(string)
# Out:
# Python

# %% [markdown]
# ## String Methods:

# %% [markdown]
# ##### Write a Python program that takes a string, strM = “Python beginner tutorial” and perform the following tasks:

# %%
strM="Python beginner tutorial"

# %% [markdown]
# ##### a. Convert the sentence to uppercase

# %%
print(strM.upper())
# Out:
# PYTHON BEGINNER TUTORIAL

# %% [markdown]
# ##### b. Convert the sentence to lowercase

# %%
print(strM.lower())
# Out:
# python beginner tutorial

# %% [markdown]
# ##### c. Use Capitalize and return the sentence to the original input form

# %%
print(strM.capitalize())
# Out:
# Python beginner tutorial

# %%
print(strM)
# Out:
# Python beginner tutorial

# %% [markdown]
# ##### d. Count the total number of occurrences of character ‘t’ in the string

# %%
count_t=strM.count('t')

# %%
print(count_t)
# Out:
# 3

# %% [markdown]
# ##### e. Replace all occurrences of “Python” with “Machine Learning” in the input string strM = “Python beginner tutorial”

# %%
strM= strM.replace("Python", "Machine Learning")

# %%
print(strM)
# Out:
# Machine Learning beginner tutorial

# %% [markdown]
# ## Tuples (Creation, Modification and Access) :

# %% [markdown]
# ##### Create 1st tuple with values -> (10, 20, 30), 2nd tuple with values -> (40, 50, 60):

# %%
tuple1 = (10,20,30)

# %%
tuple2 = (40,50,60)

# %% [markdown]
# ##### a. Concatenate the two tuples and store it in “t_combine”

# %%
t_combine = tuple1+tuple2

# %%
t_combine
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
print(t_combine)
# Out:
# (10, 20, 30, 40, 50, 60)

# %% [markdown]
# ##### b. Repeat the elements of “t_combine” 3 times

# %%
rep_t_combine = t_combine*3

# %%
rep_t_combine
# Out:
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %% [markdown]
# ##### c. Access the 3rd element from “t_combine”

# %%
print(t_combine[2])
# Out:
# 30

# %% [markdown]
# ##### d. Access the first three elements from “t_combine”

# %%
print(t_combine[0:3])
# Out:
# (10, 20, 30)

# %% [markdown]
# ##### e. Access the last three elements from “t_combine”

# %%
print(t_combine[-1])
# Out:
# 60
